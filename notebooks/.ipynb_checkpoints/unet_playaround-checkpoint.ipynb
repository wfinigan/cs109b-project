# %%
from unet_extras.zf_unet_224_model import ZF_UNET_224, dice_coef_loss, dice_coef
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
import keras.backend as K
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
model = ZF_UNET_224(weights='generator')
optim = Adam()

for i in range(39):
    model.layers[i].trainable = False

model.compile(optimizer=optim, loss=dice_coef_loss, metrics=[dice_coef])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 224, 224, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 224, 224, 32) 9248        activation_1[0][0]
# ...

# %%
CLEAN_DIR = '../clean_data'

# %%
# we create two instances with the same arguments
data_gen_args = dict(
    featurewise_center=True,
    featurewise_std_normalization=True,
    rotation_range=90,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.2,
    validation_split=.2,
    rescale=1./255,
)

image_datagen = ImageDataGenerator(**data_gen_args)
mask_datagen = ImageDataGenerator(**data_gen_args)

# Provide the same seed and keyword arguments to the fit and flow methods
seed = 1
# image_datagen.fit(images, augment=True, seed=seed)
# mask_datagen.fit(masks, augment=True, seed=seed)

image_train_generator = image_datagen.flow_from_directory(
    f'{CLEAN_DIR}/mass/train/images',
    class_mode=None,
    seed=seed,
    subset='training',
    target_size=(224, 224),
    batch_size=16,
)

image_val_generator = image_datagen.flow_from_directory(
    f'{CLEAN_DIR}/mass/train/images',
    class_mode=None,
    seed=seed,
    subset='validation',
    target_size=(224, 224),
    batch_size=16,
)

mask_train_generator = mask_datagen.flow_from_directory(
    f'{CLEAN_DIR}/mass/train/masks',
    class_mode=None,
    seed=seed,
    subset='training',
    target_size=(224, 224),
    batch_size=16,
    color_mode='grayscale'
)

mask_val_generator = mask_datagen.flow_from_directory(
    f'{CLEAN_DIR}/mass/train/masks',
    class_mode=None,
    seed=seed,
    subset='validation',
    target_size=(224, 224),
    batch_size=16,
    color_mode='grayscale'
)

# combine generators into one which yields image and masks
train_generator = zip(image_train_generator, mask_train_generator)
val_generator = zip(image_val_generator, mask_val_generator)
# Out:
# Found 621 images belonging to 1 classes.
# Found 155 images belonging to 1 classes.
# Found 621 images belonging to 1 classes.
# Found 155 images belonging to 1 classes.

# %%
data_generator_image_test = ImageDataGenerator(rescale=1./255)
data_generator_mask_test = ImageDataGenerator(rescale=1./255)

# %%
image_test_generator = data_generator_image_test.flow_from_directory(
    f'{CLEAN_DIR}/mass/test/images',
    class_mode=None,
    seed=seed,
    target_size=(224, 224),
    color_mode='rgb'
)

mask_test_generator = data_generator_mask_test.flow_from_directory(
    f'{CLEAN_DIR}/mass/test/masks',
    class_mode=None,
    seed=seed,
    target_size=(224, 224)
)

test_generator = zip(image_test_generator, mask_test_generator)
# Out:
# Found 275 images belonging to 1 classes.
# Found 275 images belonging to 1 classes.

# %%
plt.imshow(next(test_generator)[0][0])

# %%
image_datagen = ImageDataGenerator()

model.fit_generator(
    train_generator,
    steps_per_epoch=120,
    epochs=5,
    validation_data=val_generator,
    validation_steps=31
)
# Out:
# Epoch 1/5
# /usr/share/anaconda3/lib/python3.6/site-packages/keras_preprocessing/image.py:1131: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/share/anaconda3/lib/python3.6/site-packages/keras_preprocessing/image.py:1139: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# 120/120 [==============================] - 90s 750ms/step - loss: -0.1552 - dice_coef: 0.1552 - val_loss: -1.4956e-04 - val_dice_coef: 1.4956e-04
# Epoch 2/5
# 120/120 [==============================] - 73s 612ms/step - loss: -0.2538 - dice_coef: 0.2538 - val_loss: -7.3496e-04 - val_dice_coef: 7.3496e-04
# Epoch 3/5
# ...

# %%
im, mask = next(test_generator)

# %%
# Reset before each call to predict

pred = model.predict(im, steps = len(im), verbose = 1)
# Out:
# 32/32 [==============================] - 17s 543ms/step

# %%
im_num = 8

# %%
im[0].shape
# Out:
# (224, 224, 3)

# %%
plt.imshow(im[im_num])

# %%
plt.imshow(mask[im_num])

# %%
plt.imshow(pred[im_num].reshape(224,224))
